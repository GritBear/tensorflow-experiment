# %% [markdown]
# # Running Tutorial Word2Vec

# %% [markdown]
# ## Download Data

# %%
from __future__ import absolute_import
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange    # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
                'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# ## Read DataSets

# %%
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = f.read(f.namelist()[0]).split()
    return data

words = read_data(filename)
print('Data size', len(words))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0    # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words    # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# ## Function to Generate Batch

# %%
data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    
    # get size Span sentence (skip window = 1 => 3, x Y x)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    #i 0 => 3
    for i in range(batch_size // num_skips):
        target = skip_window    # target label at the center of the buffer, 1
        targets_to_avoid = [ skip_window ] # 1
        
        # 0 -> 1
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1) # random to non skip_window target
            targets_to_avoid.append(target) #new target adds to the list
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
            '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 5239 anarchism
# 3084 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3084 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %% [markdown]
# Original Sentence: anarchism originated as a term of......

# %%
batch
# Out:
# array([3084, 3084,   12,   12,    6,    6,  195,  195], dtype=int32)

# %%
labels
# Out:
# array([[5239],
#        [  12],
#        [   6],
#        [3084],
#        [ 195],
#        [  12],
#        [   6],
#        [   2]], dtype=int32)

# %% [markdown]
# ## Build Training Model

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128    # Dimension of the embedding vector.
skip_window = 1             # How many words to consider left and right.
num_skips = 2                 # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16         # Random set of words to evaluate similarity on.
valid_window = 100    # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64        # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
                tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
                tf.truncated_normal([vocabulary_size, embedding_size],
                                                        stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
            tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                                         num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
            normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
            valid_embeddings, normalized_embeddings, transpose_b=True)

# %% [markdown]
# ## Actually Training

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    tf.initialize_all_variables().run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
                batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  266.05267334
# Nearest to over: timbres, incompatibility, minimize, liters, mitsubishi, ungrammatical, progresses, basilisk,
# Nearest to s: prescient, pda, kippur, martinez, majin, pacification, requiem, emphases,
# Nearest to however: akiva, respondent, trilogy, warships, outlook, hume, buckle, conditioned,
# Nearest to on: rattus, nag, mains, superintendence, strangers, montessori, sculptured, westphalian,
# Nearest to called: retaining, decameron, ideal, rooms, cautionary, sneak, inherits, gendered,
# Nearest to other: heats, alerted, irregular, sinister, lenny, drunken, marv, lessened,
# Nearest to they: helier, roger, innocuous, acton, antioch, pending, synthase, ghostbusters,
# Nearest to five: timed, bao, promiscuous, recognising, enthroned, medical, loris, masons,
# Nearest to d: dorsey, picket, philosophical, fermion, waveguide, splicing, linnaeus, oriented,
# Nearest to is: excellency, infantry, phosphorus, naps, gg, zhejiang, mcculloch, ass,
# Nearest to these: mondo, cytosine, answer, accretion, cockpit, rampart, proclaimed, guitarist,
# Nearest to such: phrygian, excuse, colorless, sage, conform, ganymede, offences, eleusinian,
# Nearest to an: croquet, leaflet, interludes, assumed, hemp, bert, j, temple,
# Nearest to there: brett, abel, asimov, broncos, othello, im, parachute, transitory,
# Nearest to only: leviathan, cathay, bulges, quatrain, uterine, engrams, umayyads, bruckner,
# Nearest to seven: standardizing, budge, degradation, never, oil, spontaneously, arboreal, satisfiability,
# Average loss at step  2000 :  113.341506674
# Average loss at step  4000 :  52.4290016263
# Average loss at step  6000 :  33.6632212336
# Average loss at step  8000 :  23.523446559
# Average loss at step  10000 :  17.9840259223
# Nearest to over: six, reach, shock, schemata, wooden, offers, broadcasts, austin,
# Nearest to s: and, amo, the, his, of, ataxia, zero, nine,
# Nearest to however: background, trilogy, aeronautical, respondent, one, outlook, moment, biological,
# Nearest to on: in, with, and, are, princess, of, directors, prodigy,
# Nearest to called: boats, ideal, retaining, austin, adventures, wings, studio, beats,
# Nearest to other: analogue, asterism, continue, pneumonia, irregular, symbols, alerted, implicit,
# Nearest to they: rebecca, negative, undergoes, incident, cary, fall, roger, piston,
# Nearest to five: zero, eight, agave, nine, analogue, vs, mathbf, december,
# Nearest to d: agave, defensive, longer, colonies, philosophical, oriented, optical, potentially,
# Nearest to is: are, was, has, in, and, had, gb, gland,
# Nearest to these: niger, answer, alchemist, guitarist, altenberg, progressive, mathbf, properly,
# Nearest to such: phrygian, conform, colorless, knows, fao, murderer, remington, declining,
# Nearest to an: the, j, hemp, assumed, a, violations, bert, austin,
# Nearest to there: killed, dred, im, iron, cavalry, rise, brett, asimov,
# Nearest to only: mathbf, uterine, signal, assault, individual, using, five, analogue,
# Nearest to seven: zero, nine, analogue, austin, night, victoriae, six, never,
# Average loss at step  12000 :  13.8006236372
# Average loss at step  14000 :  11.7911062858
# Average loss at step  16000 :  10.0624311624
# Average loss at step  18000 :  8.682611992
# Average loss at step  20000 :  7.6899729414
# Nearest to over: nine, six, codon, reach, schemata, prostitution, three, broadcasts,
# Nearest to s: his, and, zero, amo, dasyprocta, the, reginae, ataxia,
# Nearest to however: virgil, background, aeronautical, agouti, trilogy, parapsychology, moment, tiny,
# Nearest to on: in, and, with, at, two, of, for, to,
# Nearest to called: apatosaurus, boats, and, bill, wings, adventures, satr, studio,
# Nearest to other: brighter, heats, analogue, asterism, pneumonia, irregular, symbols, continue,
# Nearest to they: he, there, norma, fall, cary, belisarius, it, which,
# Nearest to five: zero, eight, nine, six, four, three, seven, two,
# Nearest to d: b, serapeum, apostasy, agave, fermion, colonies, theologian, goldbach,
# Nearest to is: was, are, has, agouti, by, were, in, for,
# Nearest to these: niger, progressive, nosed, guitarist, the, forts, answer, altenberg,
# Nearest to such: sage, dasyprocta, excuse, murderer, a, batll, conform, declining,
# Nearest to an: the, assumed, hemp, bert, j, sq, violations, thelema,
# Nearest to there: it, they, killed, im, dred, he, iron, norma,
# Nearest to only: uterine, mathbf, signal, five, assault, grades, dasyprocta, workers,
# Nearest to seven: nine, eight, zero, six, dasyprocta, five, four, three,
# Average loss at step  22000 :  7.29626244366
# Average loss at step  24000 :  7.0853593049
# Average loss at step  26000 :  6.73730674076
# Average loss at step  28000 :  6.1651505028
# Average loss at step  30000 :  6.18517169428
# Nearest to over: six, for, hauge, prostitution, nine, broadcasts, and, mitsubishi,
# Nearest to s: his, and, zero, of, aorta, the, two, reginae,
# Nearest to however: almighty, agouti, abitibi, for, and, aeronautical, virgil, parapsychology,
# Nearest to on: in, at, and, for, from, into, with, two,
# Nearest to called: apatosaurus, boats, underneath, and, satr, bill, agouti, wings,
# Nearest to other: analogue, brighter, asterism, pneumonia, rodin, heats, continue, irregular,
# Nearest to they: he, there, it, we, aba, norma, cary, belisarius,
# Nearest to five: eight, four, six, zero, seven, three, nine, two,
# Nearest to d: b, agave, serapeum, fermion, apostasy, theologian, colonies, evaluated,
# Nearest to is: was, are, has, aorta, were, agouti, for, if,
# Nearest to these: the, abitibi, progressive, niger, which, rampart, all, nosed,
# Nearest to such: sage, murderer, dasyprocta, excuse, declining, batll, known, leaked,
# Nearest to an: the, aorta, assumed, violations, bert, j, callisto, hemp,
# Nearest to there: they, it, he, often, killed, im, which, norma,
# Nearest to only: uterine, signal, aorta, mathbf, five, cpa, grades, warrior,
# Nearest to seven: eight, nine, six, four, five, zero, three, dasyprocta,
# Average loss at step  32000 :  5.86448764873
# Average loss at step  34000 :  5.85175955224
# Average loss at step  36000 :  5.67212337399
# Average loss at step  38000 :  5.27609793115
# Average loss at step  40000 :  5.44498665243
# Nearest to over: six, three, five, seven, four, nine, reuptake, through,
# Nearest to s: his, and, aorta, reginae, fao, amo, zero, truetype,
# Nearest to however: but, that, and, almighty, agouti, parapsychology, aeronautical, virgil,
# Nearest to on: at, in, with, from, into, for, and, upon,
# Nearest to called: and, apatosaurus, UNK, underneath, boats, anubis, agouti, columbians,
# Nearest to other: brighter, analogue, two, asterism, mig, pneumonia, irregular, ole,
# Nearest to they: he, there, it, we, aba, alexandrina, not, norma,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to d: b, UNK, fermion, serapeum, agave, recitative, apostasy, goldbach,
# Nearest to is: was, has, are, aorta, became, were, agouti, dasyprocta,
# Nearest to these: which, all, some, that, the, abitibi, progressive, stitch,
# Nearest to such: sage, murderer, dasyprocta, cassation, declining, known, excuse, colorless,
# Nearest to an: aorta, the, assumed, croquet, hemp, violations, thelema, awe,
# Nearest to there: they, it, he, which, often, killed, im, norma,
# Nearest to only: signal, uterine, mathbf, three, byelorussian, aorta, five, aquifer,
# Nearest to seven: eight, six, nine, four, five, zero, three, dasyprocta,
# Average loss at step  42000 :  5.32173791456
# Average loss at step  44000 :  5.33779773259
# Average loss at step  46000 :  5.26957367063
# Average loss at step  48000 :  5.0199949187
# Average loss at step  50000 :  5.12956093085
# Nearest to over: seven, through, three, prostitution, six, tethys, incompatibility, hauge,
# Nearest to s: his, and, zero, aorta, fao, reginae, truetype, amo,
# Nearest to however: but, that, almighty, agouti, and, though, segment, parapsychology,
# Nearest to on: at, in, upon, into, through, and, around, from,
# Nearest to called: apatosaurus, and, underneath, thibetanus, anubis, wayne, boats, satr,
# Nearest to other: brighter, analogue, many, asterism, mig, two, some, pneumonia,
# Nearest to they: he, there, we, it, not, who, alexandrina, aba,
# Nearest to five: four, six, seven, three, eight, zero, nine, two,
# Nearest to d: b, fermion, serapeum, haman, agave, apostasy, recitative, goldbach,
# Nearest to is: was, are, has, became, were, aorta, agouti, thibetanus,
# Nearest to these: some, all, which, many, progressive, stitch, abitibi, the,
# Nearest to such: sage, cassation, murderer, known, declining, dasyprocta, served, well,
# Nearest to an: aorta, hemp, assumed, croquet, awe, colored, the, eliminated,
# Nearest to there: they, it, he, which, often, killed, norma, im,
# Nearest to only: signal, uterine, thibetanus, now, mathbf, warrior, aquifer, cpa,
# Nearest to seven: eight, six, four, five, nine, three, zero, dasyprocta,
# Average loss at step  52000 :  5.15444877589
# Average loss at step  54000 :  5.11335232961
# Average loss at step  56000 :  5.06927730274
# Average loss at step  58000 :  5.0956648581
# Average loss at step  60000 :  4.93068676424
# Nearest to over: through, callithrix, seven, prostitution, five, four, incompatibility, tethys,
# Nearest to s: his, aorta, callithrix, zero, microsite, reginae, amo, and,
# Nearest to however: but, that, though, almighty, agouti, ssbn, where, so,
# Nearest to on: in, at, upon, through, into, around, sylia, with,
# Nearest to called: apatosaurus, and, underneath, thibetanus, wayne, shelled, agouti, cyclopes,
# Nearest to other: many, brighter, some, callithrix, analogue, mig, different, halo,
# Nearest to they: he, there, we, it, not, who, tamarin, you,
# Nearest to five: six, four, eight, three, seven, zero, nine, callithrix,
# Nearest to d: b, fermion, haman, agave, serapeum, recitative, apostasy, callithrix,
# Nearest to is: was, are, has, aorta, agouti, became, victoriae, amalthea,
# Nearest to these: some, all, many, which, the, such, progressive, abitibi,
# Nearest to such: sage, well, murderer, cassation, many, dasyprocta, served, these,
# Nearest to an: aorta, tamarin, hemp, the, colored, assumed, awe, croquet,
# Nearest to there: they, it, he, which, often, killed, still, dred,
# Nearest to only: signal, callithrix, but, uterine, now, thibetanus, wren, cpa,
# Nearest to seven: eight, six, five, nine, four, three, zero, one,
# Average loss at step  62000 :  4.79111099923
# Average loss at step  64000 :  4.80322927535
# Average loss at step  66000 :  4.95460621274
# Average loss at step  68000 :  4.90465127289
# Average loss at step  70000 :  4.77122139239
# Nearest to over: through, callithrix, four, six, three, prostitution, five, tethys,
# Nearest to s: his, aorta, callithrix, amo, premierships, microsite, resonator, reginae,
# Nearest to however: but, though, where, that, agouti, almighty, ssbn, while,
# Nearest to on: at, in, upon, through, thaler, and, around, thz,
# Nearest to called: apatosaurus, underneath, UNK, thibetanus, cyclopes, and, wayne, agouti,
# Nearest to other: many, some, brighter, callithrix, mig, different, analogue, three,
# Nearest to they: he, there, we, it, not, who, you, tamarin,
# Nearest to five: four, six, three, seven, eight, zero, nine, callithrix,
# Nearest to d: b, fermion, haman, serapeum, agave, sigmund, recitative, apostasy,
# Nearest to is: was, are, has, aorta, became, agouti, were, thaler,
# Nearest to these: some, many, all, which, such, the, upanija, their,
# Nearest to such: these, many, well, known, cassation, served, other, sage,
# Nearest to an: the, aorta, hemp, awe, crosstown, colored, tamarin, assumed,
# Nearest to there: they, it, he, which, often, still, we, she,
# Nearest to only: callithrix, but, thaler, signal, now, uterine, nonprofit, thibetanus,
# Nearest to seven: six, eight, four, five, nine, three, zero, one,
# Average loss at step  72000 :  4.79639633107
# Average loss at step  74000 :  4.76658256602
# Average loss at step  76000 :  4.88168195176
# Average loss at step  78000 :  4.79626959956
# Average loss at step  80000 :  4.80915267551
# Nearest to over: through, callithrix, four, incompatibility, headlines, prostitution, crb, candide,
# Nearest to s: reginae, his, microsite, amo, resonator, callithrix, zero, truetype,
# Nearest to however: but, that, though, although, where, while, agouti, ssbn,
# Nearest to on: in, at, upon, through, thz, thaler, around, into,
# Nearest to called: apatosaurus, underneath, irbms, thibetanus, cyclopes, and, wayne, iit,
# Nearest to other: many, brighter, some, different, mig, callithrix, analogue, maccabees,
# Nearest to they: he, there, we, it, not, you, who, tamarin,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to d: b, fermion, crb, agave, iit, goldbach, serapeum, sigmund,
# Nearest to is: was, has, are, aorta, agouti, thaler, became, thibetanus,
# Nearest to these: some, many, all, such, which, several, upanija, there,
# Nearest to such: these, well, many, known, served, cassation, sage, murderer,
# Nearest to an: croquet, aorta, crosstown, apotheosis, tamarin, colored, assumed, awe,
# Nearest to there: they, it, he, which, often, still, she, we,
# Nearest to only: but, crb, callithrix, thaler, nonprofit, signal, now, uterine,
# Nearest to seven: six, five, eight, four, nine, three, zero, callithrix,
# Average loss at step  82000 :  4.80694453883
# Average loss at step  84000 :  4.77815060914
# Average loss at step  86000 :  4.75843917775
# Average loss at step  88000 :  4.69070377052
# Average loss at step  90000 :  4.73667500556
# Nearest to over: through, callithrix, prostitution, headlines, incompatibility, crb, candide, five,
# Nearest to s: his, microsite, reginae, resonator, premierships, callithrix, nightlife, zero,
# Nearest to however: but, that, though, while, although, almighty, agouti, ssbn,
# Nearest to on: at, upon, in, through, thaler, thz, into, around,
# Nearest to called: apatosaurus, underneath, thibetanus, cyclopes, irbms, iit, agouti, used,
# Nearest to other: many, some, different, brighter, various, callithrix, maccabees, analogue,
# Nearest to they: he, we, there, it, you, who, not, she,
# Nearest to five: seven, four, eight, six, three, nine, two, zero,
# Nearest to d: b, crb, fermion, zero, agave, iit, six, recitative,
# Nearest to is: was, has, are, aorta, if, agouti, thaler, microsite,
# Nearest to these: some, many, such, all, which, several, both, upanija,
# Nearest to such: these, well, many, served, known, cassation, murderer, semites,
# Nearest to an: aorta, croquet, crosstown, colored, apotheosis, hemp, tamarin, the,
# Nearest to there: they, it, he, which, she, often, still, we,
# Nearest to only: crb, callithrix, but, thaler, nonprofit, now, thibetanus, cpa,
# Nearest to seven: five, eight, six, four, three, nine, zero, callithrix,
# Average loss at step  92000 :  4.70442022502
# Average loss at step  94000 :  4.61494046807
# Average loss at step  96000 :  4.73078463006
# Average loss at step  98000 :  4.61062114233
# Average loss at step  100000 :  4.68390504825
# Nearest to over: through, four, callithrix, three, prostitution, crb, headlines, six,
# Nearest to s: his, microsite, resonator, aorta, reginae, callithrix, the, pka,
# Nearest to however: but, while, although, that, though, and, where, ssbn,
# Nearest to on: upon, in, at, through, around, thaler, thz, into,
# Nearest to called: and, apatosaurus, underneath, used, thibetanus, cyclopes, iit, UNK,
# Nearest to other: many, various, different, brighter, some, callithrix, others, analogue,
# Nearest to they: he, there, we, it, you, who, not, she,
# Nearest to five: four, seven, six, three, eight, zero, nine, two,
# Nearest to d: b, crb, agave, iit, fermion, callithrix, microsite, serapeum,
# Nearest to is: was, has, are, aorta, microsite, agouti, became, thaler,
# Nearest to these: some, many, such, all, several, which, various, both,
# Nearest to such: these, well, many, known, served, cassation, murderer, semites,
# Nearest to an: aorta, croquet, the, crosstown, colored, thelema, universalists, tamarin,
# Nearest to there: they, it, he, which, still, often, we, she,
# Nearest to only: crb, callithrix, but, thaler, signal, now, thibetanus, cpa,
# Nearest to seven: six, eight, four, five, nine, three, zero, callithrix,

# %% [markdown]
# ## Present Result

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))    #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                                 xy=(x, y),
                                 xytext=(5, 2),
                                 textcoords='offset points',
                                 ha='right',
                                 va='bottom')

    plt.savefig(filename)

try:
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print("Please install sklearn and matplotlib to visualize embeddings.")
